# %%
import numpy as np
from scipy import linalg
from scipy.sparse import diags
import pandas as pd

from semester6 import sle
from semester6.utils import print_matrix


def answer(a: np.ndarray, b: np.ndarray, eps: float = 10e-6) -> None:
    print("Исходная матрица:", end="")
    print_matrix(a)

    print("Правая часть:", end="")
    print_matrix(b)

    print("ε =", eps)
    (x_iter, x_iter_count) = sle.solve(a, b, sle.SolveMethod.SimpleIteration, eps=eps)
    (x_seidel, x_seidel_count) = sle.solve(a, b, sle.SolveMethod.Seidel, eps=eps)

    print("Решение методом простой итерации", end="")
    print_matrix(x_iter)
    print("Количество итераций:", x_iter_count)

    print("Решение методом Зейделя", end="")
    print_matrix(x_seidel)
    print("Количество итераций:", x_seidel_count)

    diff = linalg.norm(x_iter - x_seidel)
    print("||x_iter - x_seidel|| =", diff)

# %%
a1 = np.array([[2, -1, 0], [-1, 2, -1], [0, -1, 2]])
b1 = np.array([[0.5], [1], [1.5]])
answer(a1, b1)
# Out:
# Исходная матрица:
#  2 -1  0
# -1  2 -1
#  0 -1  2
# Правая часть:
# 0.5
# 1.0
# 1.5
# ε = 1e-05
# Решение методом простой итерации
# 1.25
# 2.00
# 1.75
# Количество итераций: 108
# Решение методом Зейделя
# 1.249999
# 1.999999
# 1.749999
# Количество итераций: 20
# ||x_iter - x_seidel|| = 1.3228757794430863
# /home/wowaster/uni/spbu-computational-workshop/semester6/sle.py:98: RuntimeWarning: divide by zero encountered in scalar divide
#   diff = norm_big_b / (1 - norm_big_b) * linalg.norm(x - prev_x)
# /home/wowaster/uni/spbu-computational-workshop/semester6/sle.py:98: RuntimeWarning: invalid value encountered in scalar multiply
#   diff = norm_big_b / (1 - norm_big_b) * linalg.norm(x - prev_x)

# %%
a2 = np.array([[25, 15, -5], [15, 18, 0], [-5, 0, 11]])
b2 = np.array([[1], [1], [1]])
answer(a2, b2)
# Out:
# Исходная матрица:
# 25 15 -5
# 15 18  0
# -5  0 11
# Правая часть:
# 1
# 1
# 1
# ε = 1e-05
# Решение методом простой итерации
# 0.060740
# 0.004939
# 0.118518
# Количество итераций: 41
# Решение методом Зейделя
# 0.060740
# 0.004939
# 0.118518
# Количество итераций: 19
# ||x_iter - x_seidel|| = 0.19673501930743745

# %%
n = 5
k = [1.5 * np.ones(n - 1), 5 * np.ones(n), -2.7 * np.ones(n - 1)]
offset = [-1, 0, 1]
a3 = diags(k, offset).toarray()
b3 = np.array([[1], [2], [3], [4], [5]])

pd.options.display.float_format = "{:,.16f}".format
answer(a3, b3, eps=10e-12)
# Out:
# Исходная матрица:
# 5.0000000000000000 -2.7000000000000002  0.0000000000000000  0.0000000000000000  0.0000000000000000
# 1.5000000000000000  5.0000000000000000 -2.7000000000000002  0.0000000000000000  0.0000000000000000
# 0.0000000000000000  1.5000000000000000  5.0000000000000000 -2.7000000000000002  0.0000000000000000
# 0.0000000000000000  0.0000000000000000  1.5000000000000000  5.0000000000000000 -2.7000000000000002
# 0.0000000000000000  0.0000000000000000  0.0000000000000000  1.5000000000000000  5.0000000000000000
# Правая часть:
# 1
# 2
# 3
# 4
# 5
# ε = 1e-11
# Решение методом простой итерации
# 0.5807143667916408
# 0.7050266051710281
# 0.8874831763129790
# 0.9240576997472105
# 0.7227826900756164
# Количество итераций: 74
# Решение методом Зейделя
# 0.5807143667920648
# 0.7050266051711349
# 0.8874831763121213
# 0.9240576997473252
# 0.7227826900758024
# Количество итераций: 39
# ||x_iter - x_seidel|| = 0.8923951620394616

# %%
a4 = np.array([[15, 6, 7], [2, -4, -2], [3, 2, 6]])
b4 = np.array([[1.5], [1.5], [1.5]])
answer(a4, b4, eps=10e-15)
# Out:
# Исходная матрица:
# 15  6  7
#  2 -4 -2
#  3  2  6
# Правая часть:
# 1.5000000000000000
# 1.5000000000000000
# 1.5000000000000000
# ε = 1e-14
# Решение методом простой итерации
#  0.1317567567567570
# -0.4814189189189189
#  0.3445945945945948
# Количество итераций: 45
# Решение методом Зейделя
#  0.1317567567567566
# -0.4814189189189191
#  0.3445945945945947
# Количество итераций: 30
# ||x_iter - x_seidel|| = 1.4856531755175884

# %%
# Requires bcsstk05 from SuiteSparse Matrix Collection
from scipy import io

a5 = io.mmread("bcsstk05/bcsstk05.mtx").toarray()
b5 = np.ones((a5.shape[0], 1))

x5 = linalg.solve(a5, b5)
print(x5)
(x_seidel, x_seidel_count) = sle.solve(a5, b5, sle.SolveMethod.Seidel, eps=10e-15)
# Out:
# [[ 3.37934320e-03]
#  [ 8.90768349e-05]
#  [ 3.40611060e-03]
#  [ 2.96380176e-03]
#  [-5.24186039e-04]
#  [ 2.96820399e-03]
#  [ 2.96549603e-03]
#  [-2.27447956e-04]
#  [ 2.96980406e-03]
#  [ 2.96572398e-03]
#  [ 8.37954960e-05]
#  [ 2.98627352e-03]
#  [ 2.95420877e-03]
#  [ 7.71855914e-04]
#  [ 3.03866283e-03]
#  [ 2.94534621e-03]
#  [ 4.00402935e-04]
#  [ 2.98754237e-03]
#  [ 2.95097952e-03]
#  [ 8.84120009e-05]
#  [ 2.97165411e-03]
#  [ 2.67021060e-03]
#  [-2.25509339e-04]
#  [ 2.68030468e-03]
#  [ 2.68204352e-03]
#  [ 8.17004802e-05]
#  [ 2.68835345e-03]
#  [ 2.66950726e-03]
#  [ 3.94500840e-04]
#  [ 2.69631480e-03]
#  [ 2.64618916e-03]
#  [ 8.66670863e-05]
#  [ 2.67366928e-03]
#  [ 2.38598255e-03]
#  [-6.32595002e-04]
#  [ 2.38125977e-03]
#  [ 2.38522230e-03]
#  [-2.18423118e-04]
#  [ 2.37867219e-03]
#  [ 2.38371568e-03]
#  [ 7.85961799e-05]
#  [ 2.39480900e-03]
#  [ 2.36958363e-03]
#  [ 9.72241889e-04]
#  [ 2.47063201e-03]
#  [ 2.36164704e-03]
#  [ 3.81381372e-04]
#  [ 2.39441378e-03]
#  [ 2.36972760e-03]
#  [ 8.39848636e-05]
#  [ 2.38127277e-03]
#  [ 2.11081346e-03]
#  [-2.00698994e-04]
#  [ 2.10841166e-03]
#  [ 2.10326359e-03]
#  [ 3.59776011e-13]
#  [ 8.46078375e-14]
#  [-5.92831990e-14]
#  [ 3.52508387e-13]
#  [ 6.63216227e-14]
#  [-3.73449102e-14]
#  [ 3.55096161e-13]
#  [-8.31303681e-14]
#  [-6.29160352e-14]
#  [ 2.41170040e-13]
#  [-6.16167545e-14]
#  [-3.00749009e-14]
#  [ 2.42591754e-13]
#  [ 7.86715392e-14]
#  [-3.94533581e-14]
#  [ 2.37752201e-13]
#  [ 6.13797750e-14]
#  [-2.70222213e-14]
#  [ 2.39267482e-13]
#  [-7.12541327e-14]
#  [-9.02084397e-14]
#  [ 1.52446198e-13]
#  [-5.27751128e-14]
#  [-1.97294980e-14]
#  [ 1.53475106e-13]
#  [ 6.75375148e-14]
#  [-2.57936034e-14]
#  [ 1.50019754e-13]
#  [ 5.25321973e-14]
#  [-1.73476684e-14]
#  [ 1.50914329e-13]
#  [-6.64778901e-14]
#  [-2.81802576e-14]
#  [ 4.36114090e-14]
#  [-2.88949637e-14]
#  [ 6.58110719e-17]
#  [ 4.51057919e-14]
#  [ 3.70819606e-14]
#  [-1.25041579e-14]
#  [ 4.26405601e-14]
#  [ 2.86783672e-14]
#  [-7.40970870e-16]
#  [ 4.40824677e-14]
#  [-3.67589158e-14]
#  [-1.23258066e-14]]

# %%
print(x_seidel_count)
# Out:
# 15175

# %%
(x_s, x_s_count) = sle.solve(a5, b5, sle.SolveMethod.SimpleIteration, eps=10e-15)

# %%
print(x_s_count)
# Out:
# 137714

# %%
print(x5 - x_s)
# Out:
# [[ 1.38353951e-11]
#  [ 8.48865249e-15]
#  [ 9.29823276e-12]
#  [ 1.18195133e-11]
#  [-3.13671886e-12]
#  [ 7.87471477e-12]
#  [ 1.18552325e-11]
#  [-1.20700401e-12]
#  [ 7.93507794e-12]
#  [ 1.18654509e-11]
#  [ 2.53173825e-13]
#  [ 8.02393265e-12]
#  [ 1.18193688e-11]
#  [ 3.15413234e-12]
#  [ 8.26061832e-12]
#  [ 1.17616030e-11]
#  [ 1.22446459e-12]
#  [ 8.02666527e-12]
#  [ 1.17722217e-11]
#  [-2.36388274e-13]
#  [ 7.93184528e-12]
#  [ 1.05077743e-11]
#  [-1.18594717e-12]
#  [ 7.04304540e-12]
#  [ 1.04850577e-11]
#  [ 2.46794040e-13]
#  [ 7.09454674e-12]
#  [ 1.04153457e-11]
#  [ 1.20316479e-12]
#  [ 7.13253978e-12]
#  [ 1.03918744e-11]
#  [-2.29871664e-13]
#  [ 7.00632174e-12]
#  [ 9.07374740e-12]
#  [-3.87384721e-12]
#  [ 6.03047733e-12]
#  [ 9.11400512e-12]
#  [-1.13569183e-12]
#  [ 6.10823545e-12]
#  [ 9.12273989e-12]
#  [ 2.33675668e-13]
#  [ 6.19864793e-12]
#  [ 9.07350670e-12]
#  [ 3.89230954e-12]
#  [ 6.48998130e-12]
#  [ 9.02225733e-12]
#  [ 1.15246322e-12]
#  [ 6.19337437e-12]
#  [ 9.03188939e-12]
#  [-2.16275836e-13]
